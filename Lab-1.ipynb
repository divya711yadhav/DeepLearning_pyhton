# %% [markdown]
# # Lab1. Python Functions and Numpy

# %% [markdown]
# ### Learning Outcomes
# After completing this lab, students will be able to
#  Implement python functions
#  Use numpy functions and numpy matrix/vector operations
#  Vectorize code

# %% [markdown]
# ### Perform the following activities

# %% [markdown]
# ### Part-I: Write a method for sigmoid function

# %%
# 1. Write a function, mysigmoid(x), that takes the real number x and returns the sigmoid value using math.exp()

import math

def mysigmoid(x):
    s=1/(1+math.exp(-x))
    return s

# %%
# 2. Call mysigmoid() with x=4 and print the sigmoid value of 4.

mysigmoid(4)
# Out:
# 0.9820137900379085

# %%
# 3. Now, find the sigmoid values for x=[1, 2, 3]. Observe the results.

x=[1,2,3]

for i in x:
    print(mysigmoid(i))
# Out:
# 0.7310585786300049
# 0.8807970779778823
# 0.9525741268224334

# %%
# 4. Rewrite mysigmoid() using np.exp() function.

import numpy as np

def mysigmoid1(x):
    s=1./(1+np.exp(-x))
    return s

# %%
mysigmoid1(4)
# Out:
# 0.9820137900379085

# %%
# 5. Now call your function with x=[1, 2, 3] and observe the results

x=[1,2,3]

for i in x:
    print(mysigmoid1(i))
# Out:
# 0.7310585786300049
# 0.8807970779778823
# 0.9525741268224334

# %% [markdown]
# ### Part-II: Gradient or derivative of sigmoid function

# %% [markdown]
# We compute gradients to optimize loss functions using backpropagation.
# s_derivative = s * (1 – s), where s = sigmoid(X)
# Write a function, sig_derivative(s) that returns the gradient of s.
# You should call your earlier function, mysigmoid() to compute the sigmoid value

# %%
s=mysigmoid(i)

# %%
def sig_derivative(x):
    s_derivative=s*(1-s)
    return s_derivative

# %%
sig_derivative(s)
# Out:
# 0.017662706213291107

# %% [markdown]
# ### Part-III: Write a method image_to_vector()
#  X.shape is used to get the shape (dimension) of a matrix/vector X.
#  X.reshape(...) is used to reshape X into some other dimension.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Read Images
img = mpimg.imread(r"C:\Users\yokes\Downloads\wallpaperflare.com_wallpaper.jpg")

# Output Images
plt.imshow(img)

# %%
v=img.shape
# Out:
# (1080, 1920, 3)

# %%
v = img.reshape((img.shape[0]*img.shape[1], img.shape[2])) 
#img.shape[0] = a ; img.shape[1] = b ; img.shape[2] = c

# %%
v.shape
# Out:
# (2073600, 3)

# %%
def image_to_vector(v):
    a=img.shape[0]
    b=img.shape[1]
    c=img.shape[2]
    v1=a*b
    reshape=(v1,c)
    return reshape

# %%
image_to_vector(v)
# Out:
# (2073600, 3)

# %% [markdown]
# ### Part-IV: Write a method normalizeRows()

# %% [markdown]
# Implement normalizeRows() to normalize the rows of a matrix. After
# applying this function to an input matrix x, each row of x should be a vector
# of unit length (meaning length 1). You can use np.linalg.norm() method.

# %%
def normalizeRows(x):
    
    ### START CODE HERE ### (≈ 2 lines of code)
    # Compute x_norm as the norm 2 of x. Use np.linalg.norm(..., ord = 2, axis = ..., keepdims = True)
    x_norm = np.linalg.norm(x, ord = 2, axis = 1, keepdims = True)
    
    # Divide x by its norm.
    x = x/x_norm
    ### END CODE HERE ###

    return x

# %%
x = np.array([
    [0, 3, 4],
    [1, 6, 4]])
print("normalizeRows(x) = " + str(normalizeRows(x)))
# Out:
# normalizeRows(x) = [[0.         0.6        0.8       ]
#  [0.13736056 0.82416338 0.54944226]]

# %% [markdown]
# ### Part-V: Multiplication and Vectorization Operations

# %%
x1 = [9, 2, 5]
x2 = [7, 2, 2]

x3 = [9, 2, 5, 0, 0, 7, 5, 0, 0, 0, 9, 2, 5, 0, 0, 4, 5, 7]
x4 = [7, 2, 2, 9, 0, 9, 2, 5, 0, 0, 9, 2, 5, 0, 0, 8, 5, 3]

# %%
import time
tic = time.process_time()
dot = 0
for i in range(len(x1)):
    dot+= x1[i]*x2[i]
toc = time.process_time()
print ("dot = " + str(dot) + "\n ----- Computation time = " + str(1000*(toc - tic)) + "ms")
# Out:
# dot = 77
#  ----- Computation time = 0.0ms

# %%
import numpy as np
np.dot(x1,x2)
# Out:
# 77

# %%
tic = time.process_time()
mul = np.multiply(x1,x2)
toc = time.process_time()
print ("elementwise multiplication = " + str(mul) + "\n ----- Computation time = " + str(1000*(toc - tic)) + "ms")
# Out:
# elementwise multiplication = [63  4 10]
#  ----- Computation time = 0.0ms

# %%
np.multiply(x1,x2)
# Out:
# array([63,  4, 10])

# %%
# Vectorization

import time

# VECTORIZED ELEMENTWISE MULTIPLICATION ###
tic = time.process_time()
mul = np.multiply(x1,x2)
toc = time.process_time()
print ("elementwise multiplication = " + str(mul) + "\n ----- Computation time = " + str(1000*(toc - tic)) + "ms")

# VECTORIZED GENERAL DOT PRODUCT ###
tic = time.process_time()
dot = np.dot(x2,x1)
toc = time.process_time()
print ("gdot = " + str(dot) + "\n ----- Computation time = " + str(1000*(toc - tic)) + "ms")
# Out:
# elementwise multiplication = [63  4 10]
#  ----- Computation time = 0.0ms
# gdot = 77
#  ----- Computation time = 0.0ms

# %% [markdown]
# ### Part-VI: Implement L1 and L2 loss functions

# %%
# 1.

# GRADED FUNCTION: L1

def L1(yhat, y):
    loss = np.sum(abs(y - yhat), axis = 0, keepdims = True)
    return loss

y = np.array([1, 0, 0, 1, 1])
yhat = np.array([.9, 0.2, 0.1, .4, .9])
print("L1 = " + str(L1(yhat,y)))
# Out:
# L1 = [1.1]

# %%
# 2.

# GRADED FUNCTION: L2

def L2(yhat, y):
    loss = np.dot((y - yhat),(y - yhat))
    return loss

y = np.array([1, 0, 0, 1, 1])
yhat = np.array([.9, 0.2, 0.1, .4, .9])
print("L2 = " + str(L2(yhat,y)))
# Out:
# L2 = 0.43
